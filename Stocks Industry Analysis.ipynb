# %%
import pandas as pd
import sqlalchemy
import matplotlib.pyplot as plt
from scipy import stats
import regex
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Normalized Stock Price for Different Industries

# %%
from stocks.functions.plotting import create_normalize_plots, create_inter_industry_plot, create_VIX_plot

# %% [markdown]
# ## Analysis (Industries with Similar Trends)

# %%
df_list_similar = ['Travel', 'Auto', 'Transportation']
for i in range(len(df_list_similar)):
    create_normalize_plots(df_list_similar[i])

# %% [markdown]
# ##### As shown above, the stocks chosen within the travel, auto and the transportation industry followed simlar trends. In the travel industry in particular, although the stocks were selected from differnt stock exchanges(i.e., TSX, NYSE and NASDAQ), the behaviours for each stock were nearly identical to one another. However, due to the sample size of stocks chosen for each industry, a definitive conclusion could not be maded on rather these trends resembles the general behaviour of the industries unless more stocks are included in the analysis.
#
# ##### The similar behaviour between each stock within each industry could be due to many reasons since the valuation of stocks are very unpredictable. However, in general, the actual price of a stock is determined by market activity. Since the travel industry was hit the hardest during the COVID pandemic, the travel restrictions accross the globe might be played an essential part in the valuation of the stock prices, hence why all three stock behaved similarly.
#
# ##### As for the automotive and transportation industry, the simliarity in trends within the industry could have been due to the nature of the industry, specifically how simliar the companies operate within the industry, therefore leading to a simliar valuation during the pandemic.
#
# ##### However, due to the sample size of stocks chosen for each industry, a definitive conclusion could not be maded on rather these trends resembles the general behaviour of the industry unless more stocks are included in the analysis.

# %% [markdown]
# ## Analysis (Industries with Different Trends)

# %%
df_list_dif = ['Retail','Aerospace','Ecommerce','Entertainment']
for i in range(len(df_list_dif)):
    create_normalize_plots(df_list_dif[i])

# %% [markdown]
# ##### On the other hand, in the retail, aerospace, ecommerce and entertainment industry, the trends did not match one another as closely. However, for the aerospace, entertainment and eccommerce industry, one of the reasons why the trends did not match one another could be due to how companies selected for the analysis did not have a similar portfolio. For example, in the aerospace industry, the stocks for AIRA.FRK and BA (i.e., Airbus and Boeing, repectively) were valued similarly since both companies operate in the commercial and military aerospace industry. However, Bombardier (i.e., represented as BBD.A.TRT in the graph) mostly manufactures private jets, therefore the valuation of its stock did not resemble the other two stocks as closely.
#
# ##### As for the retail industry, although the trends do not align completly, the general shape for the trend lines are relatively similar to one another except from October 2020 to mid March 2021. That could be due to how Loblaws (i.e, represented as L.TRT in the graph) is a Canadian supermarket chain where as Costco and Walmart are multinational supermartket chains. Therefore when stricter measures such as, reducing store capacity and limiting the type of products that could be sold in store, were placed on Canadian supermarkets, it lead to discrepancy in price of Loblaws comparing to Costco and Walmart.

# %% [markdown]
# # Compare Trimmed Avgs. Across Industries

# %%
create_VIX_plot()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ...

# %%
create_inter_industry_plot()

# %% [markdown]
# ##### The above graph shows the trimmed averages (the mean calcualted with the largest and smallest 10% values excluded) of the normalized prices for each industry during the duration of the COVID pandemic.

# %% [markdown]
# ## Analysis

# %% [markdown]
# ##### As shown in the graph, the travel and the aerospace industry was the hardest hit from the pandemic in terms of stock prices since the z-score of the two industry decreased from around 2 to around -2 in the span of three and a half months during the period when the stock market was the most volatile, shown by the volatility index above. In addition, since the z-score for these two industries were significantly higher than 0 before the period when the stock market was the most volatile, it indicates that the price for its stock has yet to return to its price before the pandemic.
#
# ##### On contrary, the stock prices for the ecommerce and retail industry displayed miniscule changes during this volatile period. In fact, these two industries were part of the few that increased its valuation during the COVID pandemic shown by its negative z-score at the start of the pandemic.
#
# ##### As for the entertainment, automotive and transportation industry, the stock prices decreased during the volatile period. However, given that the stock prices for these indstries started off the pandemic at around a z-score of zero, means that the price of its stocks has returned, if not surpassed, to its pre-pandemic price.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ##### In conclusion, most stocks in the industries analysed had recovered from the price drop due to the pandemic except the stocks in the aerospace and travel indsutry. However, in order to produce a more accurate representation of each industry, more stocks must be included in the analysis.
