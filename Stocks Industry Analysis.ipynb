# %%
import pandas as pd
import sqlalchemy
import matplotlib.pyplot as plt
from scipy import stats
import regex
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Plot Stocks in each Industry

# %%
from stocks.functions.plotting import create_normalize_plots, create_inter_industry_plot

# %%
df_list = ['Travel', 'Aerospace', 'Retail', 'Ecomm', 'Auto', 'Transportation', 'Entertainment']

# %%
for i in range(len(df_list)):
    create_normalize_plots(df_list[i])

# %% [markdown]
# # Compare Trimmed Avgs. Across Industries

# %%
create_inter_industry_plot()
